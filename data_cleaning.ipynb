# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('glassdoor_jobs_1.csv')

# %%
df.head()
# Out:
#                       Job Title             Salary Estimate  \
# 0              Business Analyst  $39K-$77K (Glassdoor est.)
# 1              Business Analyst  $39K-$77K (Glassdoor est.)
# 2  Strategy & Analytics Analyst  $39K-$77K (Glassdoor est.)
# 3      Business Systems Analyst  $39K-$77K (Glassdoor est.)
# 4           IT Business Analyst  $39K-$77K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you ready to be part of a mission that is ...     4.0
# 1  Arteriors is a team of smart, imaginative (and...     3.9
# 2  Job Summary\nResponsible for researching, anal...     2.4
# 3  ***This position is eligible for 100% work fro...     3.2
# 4  IT Business Analyst\nCorporate Headquarters\n1...     3.1
#
#           Company Name              Location          Headquarters  \
# 0         Pushpay\n4.0           Redmond, WA           Redmond, WA
# 1  Arteriors Home\n3.9        Carrollton, TX        Carrollton, TX
# 2             CSX\n2.4      Jacksonville, FL      Jacksonville, FL
# 3  Healthesystems\n3.2         United States             Tampa, FL
# 4           Uline\n3.1  Pleasant Prairie, WI  Pleasant Prairie, WI
#
#                       Size  Founded  Type of ownership  \
# 0     201 to 500 employees     2011   Company - Public
# 1      51 to 200 employees     1987  Company - Private
# 2         10000+ employees     1978   Company - Public
# 3     201 to 500 employees     2002  Company - Private
# 4  5001 to 10000 employees     1980  Company - Private
#
#                           Industry                      Sector  \
# 0     Computer Hardware & Software      Information Technology
# 1  Consumer Products Manufacturing               Manufacturing
# 2        Transportation Management  Transportation & Logistics
# 3                      IT Services      Information Technology
# 4                        Wholesale           Business Services
#
#                       Revenue                             Competitors
# 0    Unknown / Non-Applicable  Subsplash, Ministry Brands, Smartsheet
# 1    Unknown / Non-Applicable                                      -1
# 2          $10+ billion (USD)             Union Pacific, BNSF Railway
# 3  $100 to $500 million (USD)                         PMSI, myMatrixx
# 4    Unknown / Non-Applicable         The Home Depot, Foxconn, Amazon

# %%
#Remove Salary Estimate = -1
df =df[ df['Salary Estimate'] != '-1']

# %% [markdown]
# ### To do
# - Salary Parsing
# - Company name text only
# - Location
# - Age of company
# - job desc parsing

# %% [markdown]
# ## 1. Parsing Salary

# %%
salary = df['Salary Estimate'].apply(lambda x: x.split('(')[0])

#remove K and $ sign
salary = salary.apply(lambda x: x.replace('K','').replace('$',''))
salary.unique()
# Out:
# array(['39-77 ', '70-85', '39-78 ', '32-64 ', '76-90 ', '37-38 ',
#        '34-67 ', '41-80 ', '50-65 ', '48-93 ', '53-95 ', '51-94 ',
#        '43-82 '], dtype=object)

# %%
df['min_salary'] = salary.apply(lambda x: int(x.split('-')[0]))
df['max_salary'] = salary.apply(lambda x: int(x.split('-')[1]))
df['avg_salary'] = (df['min_salary']+df['max_salary'])/2
df.head(1)
# Out:
#           Job Title             Salary Estimate  \
# 0  Business Analyst  $39K-$77K (Glassdoor est.)
#
#                                      Job Description  Rating  Company Name  \
# 0  Are you ready to be part of a mission that is ...     4.0  Pushpay\n4.0
#
#       Location Headquarters                  Size  Founded Type of ownership  \
# 0  Redmond, WA  Redmond, WA  201 to 500 employees     2011  Company - Public
#
#                        Industry                  Sector  \
# 0  Computer Hardware & Software  Information Technology
#
#                     Revenue                             Competitors  \
# 0  Unknown / Non-Applicable  Subsplash, Ministry Brands, Smartsheet
#
#    min_salary  max_salary  avg_salary
# 0          39          77        58.0

# %% [markdown]
# ## 2. Company Name

# %%
df['company_txt'] = df.apply(lambda x: x['Company Name'] if x['Rating'] <0 else x['Company Name'][:-4],axis=1)
df.head(1)
# Out:
#           Job Title             Salary Estimate  \
# 0  Business Analyst  $39K-$77K (Glassdoor est.)
#
#                                      Job Description  Rating  Company Name  \
# 0  Are you ready to be part of a mission that is ...     4.0  Pushpay\n4.0
#
#       Location Headquarters                  Size  Founded Type of ownership  \
# 0  Redmond, WA  Redmond, WA  201 to 500 employees     2011  Company - Public
#
#                        Industry                  Sector  \
# 0  Computer Hardware & Software  Information Technology
#
#                     Revenue                             Competitors  \
# 0  Unknown / Non-Applicable  Subsplash, Ministry Brands, Smartsheet
#
#    min_salary  max_salary  avg_salary company_txt
# 0          39          77        58.0     Pushpay

# %% [markdown]
# ## 3. Location (State)

# %%
df['job_state'] = df['Location'].apply(lambda x: x.split(','))
df['job_state'] = df['job_state'].apply(lambda x: x[1] if len(x)==2 else x[0])
df.head(1)
# Out:
#           Job Title             Salary Estimate  \
# 0  Business Analyst  $39K-$77K (Glassdoor est.)
#
#                                      Job Description  Rating  Company Name  \
# 0  Are you ready to be part of a mission that is ...     4.0  Pushpay\n4.0
#
#       Location Headquarters                  Size  Founded Type of ownership  \
# 0  Redmond, WA  Redmond, WA  201 to 500 employees     2011  Company - Public
#
#                        Industry                  Sector  \
# 0  Computer Hardware & Software  Information Technology
#
#                     Revenue                             Competitors  \
# 0  Unknown / Non-Applicable  Subsplash, Ministry Brands, Smartsheet
#
#    min_salary  max_salary  avg_salary company_txt job_state
# 0          39          77        58.0     Pushpay        WA

# %% [markdown]
# ## 4. Is it in the headquarter?

# %%
df['is_hq'] = df.apply(lambda x: 1 if x['Headquarters'] == x['Location'] else 0,axis=1)
df.head(1)
# Out:
#           Job Title             Salary Estimate  \
# 0  Business Analyst  $39K-$77K (Glassdoor est.)
#
#                                      Job Description  Rating  Company Name  \
# 0  Are you ready to be part of a mission that is ...     4.0  Pushpay\n4.0
#
#       Location Headquarters                  Size  Founded Type of ownership  \
# 0  Redmond, WA  Redmond, WA  201 to 500 employees     2011  Company - Public
#
#                        Industry                  Sector  \
# 0  Computer Hardware & Software  Information Technology
#
#                     Revenue                             Competitors  \
# 0  Unknown / Non-Applicable  Subsplash, Ministry Brands, Smartsheet
#
#    min_salary  max_salary  avg_salary company_txt job_state  is_hq
# 0          39          77        58.0     Pushpay        WA      1

# %% [markdown]
# ## 5. Age of company

# %%
df['Age'] = df['Founded'].apply(lambda x: x if x < 1 else 2020-x)
df.head(2)
# Out:
#           Job Title             Salary Estimate  \
# 0  Business Analyst  $39K-$77K (Glassdoor est.)
# 1  Business Analyst  $39K-$77K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you ready to be part of a mission that is ...     4.0
# 1  Arteriors is a team of smart, imaginative (and...     3.9
#
#           Company Name        Location    Headquarters                  Size  \
# 0         Pushpay\n4.0     Redmond, WA     Redmond, WA  201 to 500 employees
# 1  Arteriors Home\n3.9  Carrollton, TX  Carrollton, TX   51 to 200 employees
#
#    Founded  Type of ownership  ...                  Sector  \
# 0     2011   Company - Public  ...  Information Technology
# 1     1987  Company - Private  ...           Manufacturing
#
#                     Revenue                             Competitors  \
# 0  Unknown / Non-Applicable  Subsplash, Ministry Brands, Smartsheet
# 1  Unknown / Non-Applicable                                      -1
#
#   min_salary  max_salary  avg_salary     company_txt job_state is_hq  Age
# 0         39          77        58.0         Pushpay        WA     1    9
# 1         39          77        58.0  Arteriors Home        TX     1   33
#
# [2 rows x 21 columns]

# %% [markdown]
# ## 6. Job Desc

# %%
#Excel
df['excel'] = df['Job Description'].apply(lambda x: 1 if 'excel' in x.lower() else 0)

#SQL
df['SQL'] = df['Job Description'].apply(lambda x: 1 if 'SQL' in x else 0)

#Python
df['python'] = df['Job Description'].apply(lambda x: 1 if 'python' in x.lower() else 0)

#Tableau
df['tableau'] = df['Job Description'].apply(lambda x: 1 if 'tableau' in x.lower() else 0)

# %%
df['excel'].value_counts()
# Out:
# 1    269
# 0    131
# Name: excel, dtype: int64

# %% [markdown]
# ## Save the data

# %%
df.to_csv('salary_data_cleaned.csv',index=False)
