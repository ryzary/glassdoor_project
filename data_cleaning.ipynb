# %% [markdown]
# # Data Cleaning and Feature Engineering

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('software_engineer.csv')

# %%
df.head()
# Out:
#                       Job Title              Salary Estimate  \
# 0             Software Engineer  $82K-$141K (Glassdoor est.)
# 1             Software Engineer  $82K-$141K (Glassdoor est.)
# 2       Staff Software Engineer  $82K-$141K (Glassdoor est.)
# 3             Software Engineer  $82K-$141K (Glassdoor est.)
# 4  Full Stack Software Engineer  $82K-$141K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  MedBill is looking for a Software Engineer to ...     4.4
# 1  $5,000-$10,000 Sign on Bonus\n\nTO BE CONSIDER...     4.6
# 2  As the world's leader in digital payments tech...     3.7
# 3  Augustine Consulting, Inc. is currently seekin...     4.4
# 4  Why OJO?\nWe’re on a mission to empower people...     4.7
#
#                                     Company Name                Location  \
# 0                                   MedBill\n4.4               Boone, NC
# 1  Assured Information Security, Inc. (AIS)\n4.6  Annapolis Junction, MD
# 2                                 Visa Inc.\n3.7              Austin, TX
# 3                Augustine Consulting, Inc.\n4.4        Fort Belvoir, VA
# 4                                  OJO Labs\n4.7              Austin, TX
#
#       Headquarters                  Size  Founded  Type of ownership  \
# 0   Pittsburgh, PA   51 to 200 employees     2005  Company - Private
# 1         Rome, NY  201 to 500 employees     2001  Company - Private
# 2  Foster City, CA      10000+ employees     1958   Company - Public
# 3     Monterey, CA   51 to 200 employees       -1  Company - Private
# 4       Austin, TX  201 to 500 employees     2015  Company - Private
#
#                        Industry                  Sector  \
# 0        Staffing & Outsourcing       Business Services
# 1  Computer Hardware & Software  Information Technology
# 2                   IT Services  Information Technology
# 3                    Consulting       Business Services
# 4                      Internet  Information Technology
#
#                       Revenue                             Competitors
# 0     $5 to $10 million (USD)                                      -1
# 1  $100 to $500 million (USD)                                      -1
# 2          $10+ billion (USD)  American Express, Mastercard, Discover
# 3    $10 to $25 million (USD)                                      -1
# 4    $10 to $25 million (USD)                                      -1

# %%
#Remove Salary Estimate = -1
df =df[ df['Salary Estimate'] != '-1']

# %% [markdown]
# ### To do
# - Salary Parsing
# - Company name text only
# - Location
# - Age of company
# - job desc parsing

# %% [markdown]
# ## 1. Parsing Salary

# %%
salary = df['Salary Estimate'].apply(lambda x: x.split('(')[0])

#remove K and $ sign
salary = salary.apply(lambda x: x.replace('K','').replace('$',''))
salary.unique()
# Out:
# array(['82-141 ', '77-84 ', '42-91 ', '60-127 ', '68-134 ', '46-100 ',
#        '77-81 ', '72-95 ', '72-112 ', '34-74 ', '76-77 ', '91-131 ',
#        '95-181 ', '94-179 ', '83-138 ', '41-72 ', '90-131 ', '115-129 ',
#        '38-83 ', '74-100 ', '77-112 ', '50-108 ', '53-111 ', '39-82 ',
#        '68-139 ', '49-106 ', '43-89 ', '73-97 ', '61-97 ', '66-135 '],
#       dtype=object)

# %%
df['min_salary'] = salary.apply(lambda x: int(x.split('-')[0]))
df['max_salary'] = salary.apply(lambda x: int(x.split('-')[1]))
df['avg_salary'] = (df['min_salary']+df['max_salary'])/2
df.head(1)
# Out:
#            Job Title              Salary Estimate  \
# 0  Software Engineer  $82K-$141K (Glassdoor est.)
#
#                                      Job Description  Rating  Company Name  \
# 0  MedBill is looking for a Software Engineer to ...     4.4  MedBill\n4.4
#
#     Location    Headquarters                 Size  Founded  Type of ownership  \
# 0  Boone, NC  Pittsburgh, PA  51 to 200 employees     2005  Company - Private
#
#                  Industry             Sector                  Revenue  \
# 0  Staffing & Outsourcing  Business Services  $5 to $10 million (USD)
#
#   Competitors  min_salary  max_salary  avg_salary
# 0          -1          82         141       111.5

# %% [markdown]
# ## 2. Company Name

# %%
# df['company_txt'] = df.apply(lambda x: x['Company Name'] if x['Rating'] <0 else x['Company Name'][:-4],axis=1)
df.head(1)
# Out:
#            Job Title              Salary Estimate  \
# 0  Software Engineer  $82K-$141K (Glassdoor est.)
#
#                                      Job Description  Rating  Company Name  \
# 0  MedBill is looking for a Software Engineer to ...     4.4  MedBill\n4.4
#
#     Location    Headquarters                 Size  Founded  Type of ownership  \
# 0  Boone, NC  Pittsburgh, PA  51 to 200 employees     2005  Company - Private
#
#                  Industry             Sector                  Revenue  \
# 0  Staffing & Outsourcing  Business Services  $5 to $10 million (USD)
#
#   Competitors  min_salary  max_salary  avg_salary
# 0          -1          82         141       111.5

# %% [markdown]
# ## 3. Location (State)

# %%
df['job_state'] = df['Location'].apply(lambda x: x.split(','))
df['job_state'] = df['job_state'].apply(lambda x: x[1] if len(x)==2 else 'na')
df.head(1)
# Out:
#            Job Title              Salary Estimate  \
# 0  Software Engineer  $82K-$141K (Glassdoor est.)
#
#                                      Job Description  Rating  Company Name  \
# 0  MedBill is looking for a Software Engineer to ...     4.4  MedBill\n4.4
#
#     Location    Headquarters                 Size  Founded  Type of ownership  \
# 0  Boone, NC  Pittsburgh, PA  51 to 200 employees     2005  Company - Private
#
#                  Industry             Sector                  Revenue  \
# 0  Staffing & Outsourcing  Business Services  $5 to $10 million (USD)
#
#   Competitors  min_salary  max_salary  avg_salary job_state
# 0          -1          82         141       111.5        NC

# %% [markdown]
# ## 4. Is it in the headquarter?

# %%
df['is_hq'] = df.apply(lambda x: 1 if x['Headquarters'] == x['Location'] else 0,axis=1)
df.head(1)
# Out:
#            Job Title              Salary Estimate  \
# 0  Software Engineer  $82K-$141K (Glassdoor est.)
#
#                                      Job Description  Rating  Company Name  \
# 0  MedBill is looking for a Software Engineer to ...     4.4  MedBill\n4.4
#
#     Location    Headquarters                 Size  Founded  Type of ownership  \
# 0  Boone, NC  Pittsburgh, PA  51 to 200 employees     2005  Company - Private
#
#                  Industry             Sector                  Revenue  \
# 0  Staffing & Outsourcing  Business Services  $5 to $10 million (USD)
#
#   Competitors  min_salary  max_salary  avg_salary job_state  is_hq
# 0          -1          82         141       111.5        NC      0

# %% [markdown]
# ## 5. Age of company

# %%
df['Age'] = df['Founded'].apply(lambda x: x if x < 1 else 2020-x)
df.head(2)
# Out:
#            Job Title              Salary Estimate  \
# 0  Software Engineer  $82K-$141K (Glassdoor est.)
# 1  Software Engineer  $82K-$141K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  MedBill is looking for a Software Engineer to ...     4.4
# 1  $5,000-$10,000 Sign on Bonus\n\nTO BE CONSIDER...     4.6
#
#                                     Company Name                Location  \
# 0                                   MedBill\n4.4               Boone, NC
# 1  Assured Information Security, Inc. (AIS)\n4.6  Annapolis Junction, MD
#
#      Headquarters                  Size  Founded  Type of ownership  \
# 0  Pittsburgh, PA   51 to 200 employees     2005  Company - Private
# 1        Rome, NY  201 to 500 employees     2001  Company - Private
#
#                        Industry                  Sector  \
# 0        Staffing & Outsourcing       Business Services
# 1  Computer Hardware & Software  Information Technology
#
#                       Revenue Competitors  min_salary  max_salary  avg_salary  \
# 0     $5 to $10 million (USD)          -1          82         141       111.5
# 1  $100 to $500 million (USD)          -1          82         141       111.5
#
#   job_state  is_hq  Age
# 0        NC      0   15
# 1        MD      0   19

# %% [markdown]
# ## 6. Job Desc

# %%
#java
df['java'] = df['Job Description'].apply(lambda x: 1 if 'java' in x.lower() else 0)

#C++
df['c_plus'] = df['Job Description'].apply(lambda x: 1 if 'c++' in x.lower() else 0)

#Python
df['python'] = df['Job Description'].apply(lambda x: 1 if 'python' in x.lower() else 0)

#PHP
#Python
df['PHP'] = df['Job Description'].apply(lambda x: 1 if 'PHP' in x else 0)

#SQL
df['SQL'] = df['Job Description'].apply(lambda x: 1 if 'SQL' in x else 0)

#html
df['html'] = df['Job Description'].apply(lambda x: 1 if 'html' in x.lower() else 0)

#CSS
df['CSS'] = df['Job Description'].apply(lambda x: 1 if 'CSS' in x else 0)

#javascript
df['javascript'] = df['Job Description'].apply(lambda x: 1 if 'javascript' in x.lower() else 0)

# %%
df['java'].value_counts()
# Out:
# 0    540
# 1    460
# Name: java, dtype: int64

# %% [markdown]
# ##  7. Simplify Title

# %%
df['Job Title'].unique()
# Out:
# array(['Software Engineer', 'Staff Software Engineer',
#        'Full Stack Software Engineer', 'Software Engineer Backend',
#        'Sytems Engineer 1', 'Backend Engineer',
#        'Java Spring Application Developer', 'Senior Software Engineer',
#        'Software Engineer I',
#        'Staff Software Engineer - Identity and Access Management',
#        'Sr. Software Engineer - Test Engineering', 'Sr Software Engineer',
#        'Design Engineer', 'Google Cloud Platform Software Engineer',
#        'Database / Application Developer',
#        'Software Development Engineer I',
#        "Software Engineer Bachelor's (Full Time) - United States",
#        'Software Engineer - Full Stack',
#        'Wireless Modem Embedded Software Engineer (Bridgewater, NJ)',
#        'Software Support Engineer',
#        'Software Assurance/Security Engineer',
#        'Software Engineer (Medical Device)', 'Software Engineer II',
#        'Production Support Engineer', 'Back-end Software Engineer',
#        'Software Developer', 'Computer Vision Software Engineer',
#        'Software Validation Engineering Manager',
#        'Sr. Software Test Engineer',
#        'Senior Software Engineer - Full Stack / Java',
#        'Thermal Mechanical Engineer',
#        'Staff Software Engineer - IVR/Genesys',
#        'Sr Software Engineer (Node.js)', 'Controls and Software Engineer',
#        'Test Engineer Virtual Hiring Event',
#        'Atlassian Software Engineer', 'Engineer Tech',
#        'Software Test Engineer', 'Systems Engineer Virtual Hiring Event',
#        'Sr. Test Automation Engineer', 'Professional Service Engineer',
#        'Senior Software Engineer - Visa Digital Developer Platform (VDDP)',
#        'Software Engineer II - EOM', 'Senior Engineer, Software',
#        'Sr. Staff Software Engineer', 'Desktop Support Engineer',
#        'Engineer II - QA', 'Software Quality Assurance Engineer',
#        'Sr Software Engineer - Microsoft Dynamics CRM',
#        'Conversion - Software Developer - G Band',
#        'Junior Software Engineer - Human Landing System (HLS)',
#        'Software Engineer III', 'Software Engineer II - EireneRx',
#        'L1 Support Engineer',
#        'Associate Software Engineer (Java, Angular, JavaScript, Cloud Computing)',
#        'Software Engineer in Test (AMP)',
#        'DIGITAL MARKETING ENGINEER - RUBY ON RAILS',
#        'Senior Software Engineer, Payments',
#        'Software Engineer, Data Platform Team', 'Test Engineer Manager',
#        'Software Developer/C# ASP.Net',
#        'Senior Software Engineer, Back-End',
#        'Software Engineer - Distributed Systems',
#        'Software Development Engineer in Test', 'Architectural Engineer',
#        'Principal Software Engineer, Federal Practice',
#        'Software Developer III', 'Data Engineer',
#        'Senior Javascript Engineer', 'Sr. Software Engineer',
#        'Senior Software Engineer, Team Lead', 'Network Engineer I',
#        'Senior Software Engineer (Back-End)',
#        'Software Engineer - DevOps',
#        'Software Engineer / Principal Software Engineer',
#        'Software Development Engineer (Frontend)',
#        'API Software Engineer', 'Software Developer II',
#        'VoIP Platform Support Engineer',
#        'Plant Engineer-Watertown Facility',
#        'Cyber Operating Systems Research Engineer',
#        'Software Engineer (Defense/Intel)', 'Avionics Software Engineer',
#        'Principal Software Engineer', 'Senior Backend Software Engineer',
#        'ServiceNow - Senior Developer: Multi', 'Software Engineer Senior',
#        'RD Software Engineer Java/C++ (Early/Mid-Career)',
#        'Manager, Software Engineering', 'GIS Software Engineer, Basic',
#        'Senior Software Engineer - Integrations',
#        'DevOps Software Development Engineer', 'DevOps Engineer',
#        'IT/OT Engineer', 'Software Engineer ll - Stargate',
#        'Embedded Software Engineer',
#        'Junior to Mid-level Software Engineer (MOSSAIC)',
#        'Senior Software Engineer, Backend (Growth)',
#        'Software Design Engineer',
#        'Software Development Engineer (Backend)',
#        'Senior Firmware Engineer', 'Senior Software Engineer, Backend',
#        'Land Rehabilitation and Maintenance (LRAM) Engineer Support',
#        'Software Developer(.NET)', 'Engineer - Software (Mid-Senior)',
#        'Software Development Engineer (Fullstack)',
#        '.Net Developer - Senior', 'Senior Software Security Engineer',
#        'Sr. Software Engineer - Front End (React/React Native)',
#        'Software Spectrum Engineer', 'Software Engineer, Principal',
#        'UMCS Network Engineer', 'Sr. Systems Engineer',
#        'Embedded Software Engineer - Aerospace & Defense',
#        'Principal Software Engineer - Five Years Distributed Systems',
#        'Senior Full Stack Software Engineer (Java/Javascript)',
#        'GUI Developer and UX Engineer',
#        'Modem Firmware Test Engineer (QCT',
#        'Mid Level Systems and Project Engineer',
#        'Principal Software Engineer (AI)',
#        'Systems Engineer AIX, Senior Level',
#        'Senior Software Engineer II -', 'Plan Check Engineer',
#        'Composite Fabricator / Engineer / Supervisor Subject Matter Expert',
#        'Senior Cloud Engineer', 'Site Reliability Engineer',
#        'Senior Controls Engineer', 'Resident Maintenance Engineer Lead',
#        '3D Software Engineer - Scene Layers',
#        'Principal Software Engineer (Kernel/Driver)',
#        'Software Developer, Senior',
#        'Direct - Software Developer - G Band',
#        'Senior Software Engineer - EOM',
#        'Senior Embedded Software Engineer, Radio',
#        'Mechanical Engineer II', 'Sr. Software Developer',
#        'Senior Software Engineer - EireneRx',
#        'Software Engineer, Senior - C++ (CoreDev)',
#        'Transportation Project Engineer and Lead Designer',
#        'Senior Embedded Software Engineer', 'Senior Electrical Engineer',
#        'Security Engineer', 'Senior Software Developer',
#        'Senior C#/.NET Developer',
#        'Senior Software Engineer - .Net (DuckCreek Developer)',
#        'Senior System Software Engineer at Vertica',
#        'Junior Software Systems Engineer', 'Software Engineer - Linux',
#        'Lead SW Engineer - Microsoft Dynamics CRM',
#        'Analytical Engineer - NVH', 'PHP Web Application Developer',
#        'Software Development Engineer', 'Software Acquisition Engineer',
#        'Software Developer 2', 'Principal Civil Engineer',
#        'Business System Engineer- Developer',
#        'Senior Software Engineer in Test',
#        'Software Engineer, Passwordless Authentication Team - Duo Security',
#        'Sr Systems Engineer I', 'Associate Systems Engineer',
#        'Software Engineer/Principal Software Engineer',
#        'Software Engineer - Specialist (Radar)',
#        'Software Engineer TACNET', 'DevOps Engineer/Architect',
#        'Software Engineer - Machine Learning/AI',
#        'Software and Data Engineer', 'Software Engineer: Computer Vision',
#        'Entry Level Traffic Engineer', 'Service Desk Engineer',
#        'Software Engineer - Full Stack Application Development',
#        'Mid/Senior Full Stack Software Engineer', '.Net Developer',
#        'Sr. CT Generation Engineer', 'YouVersion Software Engineer',
#        'LAMP Software Engineer', 'Lead Engineer*',
#        'Senior Cloud Services Monitoring Engineer',
#        'Senior C#/.NET Software Engineer',
#        'YouVersion IOS Software Engineer', 'Junior Systems Engineer II',
#        'Software Engineer (Embedded/C++)', 'Network Security Engineer',
#        'Software Engineer or Principal Software Engineer',
#        'Software Engineer - Notifications', 'Associate Software Engineer',
#        'Systems Engineer, Journeyman',
#        'Remote Sensing Sr. Software Engineer',
#        'Application Security Engineer', 'Sales Engineer',
#        '5-Axis CNC Programmer / Engineer', 'C#/.NET Software Engineer',
#        '.NET Developer',
#        'Software Development Engineer Adobe Product & Data',
#        'Sr Data Engineer (Sr BI Developer)',
#        'C++ Software Engineer - Network Dataset', 'Senior .NET Developer',
#        'Maintenance Engineer',
#        'Senior, Security Engineer (Active Directory)',
#        'Senior Software Engineer - Duo Security',
#        'Cloud Software Engineer', 'Software Engineer (.NET/C#)',
#        'Hardware/Software Requirements Engineer',
#        'Sr Software Engineer / Solutions Architect - Infrastructure / Workflow',
#        'Senior Software Development Engineer',
#        'Embedded Software Engineer, Radio',
#        'Senior Software Engineer - Java', 'Project Engineer III',
#        'Senior Software Engineer - Analytics 20-0242',
#        'Senior Space Systems Engineer',
#        'Software Development Engineer II', 'Firmware Engineer',
#        'Positions: Senior Software Product Engineer – SQL ID',
#        'Software Engineer (.NET)', 'Systems Engineer',
#        'Software Engineer II - Turnkey Computer Systems',
#        'iOS/Android Runtime SDK Software Engineer',
#        'Software, Engineering Technician',
#        'Senior Level Computer Programmer', 'Jr. Systems Engineer/Analyst',
#        'Software Developer - 3D Analysis',
#        'Software Development Engineer in Test (SDET) – Graph Database Engineer and Network Analysis',
#        'Senior Software Engineer, Full Stack (Japanese Bilingual)',
#        'Senior Java Software Engineer',
#        'Software Engineer, Senior Principal',
#        'Virtualization and Cloud Engineer',
#        'Senior Software Engineer - Medication Decision Support',
#        'Senior Software Engineer - Java Developer',
#        'Manager, Technical Delivery - Lead Software Engineer',
#        'Engineer - Software (Mid-Senior) - Job ID',
#        'Systems Engineer- Junior (TS/SCI)', 'Senior Systems Engineer',
#        'D365 BC & NAV Senior Developer', 'Systems Engineer II',
#        'Customer Service Engineer', 'Sr. Data Engineer',
#        'Mod/Sim Application Software Engineer',
#        'Application Developer III - Sitecore',
#        'Senior GIS Integrations Engineer', 'Systems Engineer/Analyst',
#        'Enterprise Monitoring and Performance Engineer',
#        'Lead Embedded Software Engineer',
#        'Senior Software Engineer, AR/MR Products',
#        'Sr. Web Services Software Engineer',
#        'Senior Protection and Control Engineer',
#        'Senior Full Stack Engineer', 'Senior .NET Software Engineer',
#        'Test Systems Engineer - Expert (TS/SCI)',
#        'Combat Systems Integration Engineer', 'IT Security Engineer',
#        'Business Process Engineer', 'Model Based Systems Engineer',
#        'Senior Software Engineer - Linux/MacOS',
#        'Senior PHP Engineer (m/f/d) - EN',
#        '.Net Full Stack Senior Software Developer',
#        'Senior Project Engineer', 'Bridge Engineer',
#        'Professional Engineer Bridge Inspection Team Leaders',
#        'Senior Associate Engineer', 'Lead Software Engineer - Remote',
#        'Senior Avionics Software Engineer',
#        'Senior Cloud Software Engineer', 'Senior Server Engineer',
#        'Digital Signal Processing Engineer (TS/SCI Security Clearance Required)',
#        'Application Developer - Intermediate/Senior',
#        'Senior Software Engineer (Python)',
#        'Software Support Engineer - C#',
#        'Applications/Structural Engineer - 5 years required',
#        'Product Systems Engineer', 'Senior BizTalk Engineer',
#        'Senior Software Engineer - Windows',
#        'Senior Software Quality Assurance Engineer',
#        'Senior Process Control Application Engineer',
#        'Civil Engineer - Senior Project Manager',
#        'Senior Software Controls Engineer',
#        'Development Operations Engineer',
#        'Test Systems Engineer - Senior',
#        'Systems Engineer - Mid Level (TS/SCI)',
#        'Sr. Software Engineer (.NET)',
#        'Technical Manager Embedded Software Engineering',
#        'Director, Software Engineer - Medical Device/Digital Health',
#        'Unified Communications Engineer',
#        'SAP Commerce Cloud (SAP Hybris) Software Developer',
#        'Civil Structural Engineer PE',
#        'Sr. Systems Engineer, Storage and Virtualization',
#        'Lead Cybersecurity Engineer',
#        'Software Engineer - Platform and System Level Software Development',
#        'Senior Manager, Software Engineering',
#        'Reliability, Availability, and Maintainability (RAM) Engineer',
#        'Modeling Team - Senior Software Engineer, Full-Stack',
#        'Project Engineer', 'C/W-Application Developer II - IT',
#        'QA & Escalations Engineer',
#        'Senior Software Localization Engineer - Mapping & Localization',
#        'System Test Engineer', 'Staff Software Engineer - Database Team',
#        'Xamarin Mobile Developer',
#        'Sales Engineer (Demo Claims Software Product)',
#        'Software Engineer 3 - Platforms',
#        'Cyber Security Reverse Engineer',
#        'Advanced Software Engineer - Review - 20-0055',
#        'iOS Software Engineer', 'Salesforce Senior Developer',
#        'Senior Software Engineer (PHP) - Everyday Health',
#        'Sr. Backend Engineer', 'Senior Software Engineer (Care Solution)',
#        'Senior Back End Software Engineer', 'Sr. Database Engineer',
#        'Principal Software Quality Engineer',
#        'Senior Software Engineer (Appian Experience)',
#        'Principal Software Engineer - Java or Web Dev - Agile',
#        'Senior Dam Safety Engineer', 'GIS Software Engineer, Associate',
#        'Senior Back-End Software Engineer', 'Mac Software Engineer',
#        'Product Application Specialist / Inside Sales Engineer',
#        'Lead Software Developer',
#        'Associate Software Engineer - Java or Web Dev - Agile',
#        'NodeJS/MongoDB Software Engineer',
#        'Mechanical Systems Engineer, OCONUS, Afghanistan',
#        'Systems Engineer (Level 6)',
#        'Conversion - Senior Software Specialist - E Band',
#        'Senior Application Developer / Software Engineer',
#        'Software Developer - Real-Time 3D Graphics',
#        'C++ Software Engineer - VRP', 'Senior Network Engineer',
#        'Senior Front End Engineer', 'DevSecOps Engineer',
#        'Senior Staff Engineer, Software (Invest)',
#        'Senior Software Engineer, Technical Delivery',
#        'Senior DevOps Engineer',
#        'Senior Software Development Engineer - Full Stack',
#        'Software Development Engineer - SISW - MG',
#        'Senior Software Engineer - Core - 20-0078',
#        'Sr Design Assurance Engineer',
#        'Civil Project Engineer - Site Development',
#        'Industrial Control Systems Engineer',
#        'Senior Software Engineer - Analytics 20-0293',
#        'Sr. Software Engineer - Cloud Ops (Remote US)',
#        'Principal Engineer-Traction Power', 'Software Engineer 4',
#        'Senior Software Engineer - Relativity Trace 19-0731',
#        'Senior Software Engineer - Enterprise Networking - LTE/5G',
#        'Senior Software Development Engineer in Test - (SDET)',
#        'Principal/Senior Principal Software Quality Engineer, TS SCI Clearance Required, Space and Satelitte Systems',
#        'Senior Software Engineer, Wireless Access Point Development',
#        'Principal Software Engineer/Sr. Principal Software Engineer',
#        'Infrastructure Engineer', 'Senior Software Engineer (Java)',
#        'Sr. Software Engineer (JavaScript, JavaScript Frameworks, HTML/CSS)',
#        'Engineer IV', 'Lead Software Engineer - 20-0218',
#        'Senior Linux Engineer', 'Sr. High Performance Computing Engineer',
#        'R&D Software Engineer - ArcGIS Excalibur', 'Sr. Project Engineer',
#        'C++ Software Engineer - Network Analyst',
#        'Software Developer (TS/SCI required)',
#        'Lead Software Engineer - Ad Code',
#        'Sr Principal Software Engineer / Java/J2EE, Spring framework',
#        'RESEARCH COMPUTER SCIENTIST - RESEARCH ENGINEER - SR. COMPUTER SCIENTIST - SOFTWARE DEVELOPMENT',
#        'Software Development Engineer (High Performance Computing, C++) - SISW - MG',
#        'Embedded Software Engineer/Principal Embedded SoftwareEngineer with TS/SCI Clearance',
#        'Senior Information Warfare/Offensive Cyber Engineer',
#        'Senior Application Developer and Analyst',
#        'Electrical Quality Engineer',
#        'Senior Software Engineer (C#/.NET)',
#        'Lead Mechanical Design Engineer',
#        'Senior Software Test Engineer-SDWAN',
#        'Sr. Systems Engineer, Quality Systems',
#        'Staff Computer Vision Research Scientist',
#        'Principal/Sr. Principal Software Engineer',
#        'MSS Principal / Sr. Principal Software Engineer',
#        'Mid-Level Software Systems Engineer',
#        'Senior Software Test Engineer-UI Automation-SDWAN',
#        'Software Development Engineer in Test (SDET) – 3D Scene Layers',
#        'Sr. Systems Engineer, Compliance Systems',
#        'Software Development Engineer in Test (SDET) – GIS Data Management',
#        'Senior Project Process Engineer',
#        'Journeyman Cyber Security Systems Engineer/Analyst',
#        'Senior Computer Vision Engineer', 'Sr. Controls Engineer',
#        'Software Engineer III - Agile Cyber Solutions',
#        'Lead Full Stack Software Engineer',
#        'Senior Principal Software Engineer - Secure Processing',
#        'Senior Software Engineer II - EireneRx',
#        'Senior Cloud Site Reliability Engineer',
#        'Engineer II Nuclear Quality',
#        'Cyber Security Engineer - Senior (TS/SCI)',
#        'Senior Project Engineer - Piping',
#        'Senior Software Development Engineer in Test',
#        'Senior AWS Engineer',
#        'Principal Systems Engineer , Supply Chain Systems',
#        'Senior Java Software Engineer - ArcGIS Notebook Server',
#        'Sr. Software Engineer - C/Kernel Development / WiFi Access Points',
#        'Lead Finite Element Analyst/Engineer',
#        'Sr. Software Developer (React)',
#        'Senior Cloud Automation Engineer',
#        'Senior Geotechnical Engineer and Geotechnical Engineers',
#        'Senior Software Engineer (Embedded/C++)',
#        'Senior Software Engineer: Trajectory Planning',
#        'Senior Embedded Software/Firmware Engineer, Technical Lead',
#        'Sr. DevOps Engineer', 'Software Engineer, Inventor Vault',
#        'Sr. Software Engineer - Quality Database Engineering (Remote US)',
#        'Sr. Software Engineer - Performance Engineering (Remote US)',
#        'Manufacturing Engineer',
#        'Core Services - Senior Software Engineer, UI',
#        'Advanced Software Engineer- 20-0149',
#        'Open Source - Senior Software Engineer',
#        'Software Developer - Raster', 'Senior Android Engineer (SF)',
#        'Embedded Software Co-Op',
#        'Advanced Software Engineer - Core - 20-0083',
#        'Security Engineer - ArcGIS Enterprise',
#        'Staff Engineer, Software UI- 200191',
#        'R&D Principal Software Engineer - Medical Device',
#        'Senior Application Developer-Marlborough or Chelmsford',
#        'Senior Front End Software Engineer',
#        'Software Systems Engineer I', 'Network Engineer',
#        'Software QA Engineer - Manual Testing, SSIS, T-SQL, SQL Server',
#        'C# Software Engineer - Feature Services',
#        'Software Engineer: Motion Control',
#        'Principal Embedded Software Engineer - Medical Device',
#        'Sr. Application Developer', 'IT NETWORK ENGINEER II (VOICE)',
#        'Cloud Engineer - Mid Level', 'Software Application Engineer',
#        'Advanced Software Engineer - Relativity Trace 19-0732',
#        'Experienced Android Mobile Developer',
#        'Senior Software Account Manager, Mobile and IoT',
#        'AGM Senior Engineer', 'AD Senior Engineer', 'Project Engineer II',
#        'Software QA Networking Engineer – System-Test SDWAN',
#        'Software Engineering, Senior Associate',
#        'Sr Software Engineer (ETL, Informatica IDQ/PowerCenter)',
#        'Sr Software Engineer (MDM, Informatica MDM)',
#        'Senior Software Engineer, Application Security',
#        'Customer Communication Management (CCM) Software Engineer II (Quadient Inspire)',
#        'UAS Software Engineer Mid to Senior Level'], dtype=object)

# %%
def title_simplifier(title):
    if 'software' in title.lower():
        return 'software engineer'
    else:
        return 'na'

# %%
df['job_simplified'] = df['Job Title'].apply(title_simplifier)

# %%
df['job_simplified'].value_counts()
# Out:
# software engineer    668
# na                   332
# Name: job_simplified, dtype: int64

# %% [markdown]
# # 8. Seniority

# %%
def seniority(title):
    if 'sr.' in title.lower() or 'senior' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
        return 'senior'
    elif 'jr.' in title.lower() or 'junior' in title.lower() or 'intern' in title.lower() or 'internship' in title.lower():
        return 'junior'
    else:
        return 'na'

# %%
df['seniority'] = df['Job Description'].apply(seniority)
df['seniority'].value_counts()
# Out:
# senior    707
# na        211
# junior     82
# Name: seniority, dtype: int64

# %% [markdown]
# # 9. Job desc length

# %%
df['desc_len'] = df['Job Description'].apply(lambda x: len(x))
df['desc_len']
# Out:
# 0      2740
# 1      6014
# 2      6104
# 3      2295
# 4      3597
#        ...
# 995    4952
# 996    3381
# 997    4874
# 998    5837
# 999    3743
# Name: desc_len, Length: 1000, dtype: int64

# %% [markdown]
# # 10. Competitor count

# %%
df['Competitors']
# Out:
# 0                                          -1
# 1                                          -1
# 2      American Express, Mastercard, Discover
# 3                                          -1
# 4                                          -1
#                         ...
# 995                                        -1
# 996               Zillow, Trulia, Realtor.com
# 997                                        -1
# 998      Applied Materials, KLA, Lam Research
# 999                                        -1
# Name: Competitors, Length: 1000, dtype: object

# %%
df['competitors_count'] = df['Competitors'].apply(lambda x: len(x.split(',')) if x !='-1' else 0)
df['competitors_count']
# Out:
# 0      0
# 1      0
# 2      3
# 3      0
# 4      0
#       ..
# 995    0
# 996    3
# 997    0
# 998    3
# 999    0
# Name: competitors_count, Length: 1000, dtype: int64

# %% [markdown]
# ## Save the data

# %%
df.to_csv('salary_data_cleaned.csv',index=False)
