# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('glassdoor_jobs.csv')

# %%
df.head()
# Out:
#                       Job Title             Salary Estimate  \
# 0      Business Systems Analyst  $39K-$77K (Glassdoor est.)
# 1      Business Systems Analyst  $39K-$77K (Glassdoor est.)
# 2              Business Analyst  $39K-$77K (Glassdoor est.)
# 3  Strategy & Analytics Analyst  $39K-$77K (Glassdoor est.)
# 4      Business Systems Analyst  $39K-$77K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  ***This position is eligible for 100% work fro...     3.2
# 1  Client is seeking Business Systems analysts to...     4.5
# 2  Are you ready to be part of a mission that is ...     4.0
# 3  Job Summary\nResponsible for researching, anal...     2.4
# 4  MBC is a fast-growing firm that is seeking Bus...     3.7
#
#                         Company Name          Location      Headquarters  \
# 0                Healthesystems\n3.2     United States         Tampa, FL
# 1  Peterson Technology Partners\n4.5    Northbrook, IL    Park Ridge, IL
# 2                       Pushpay\n4.0       Redmond, WA       Redmond, WA
# 3                           CSX\n2.4  Jacksonville, FL  Jacksonville, FL
# 4     Morgan Borszcz Consulting\n3.7     Arlington, VA     Arlington, VA
#
#                    Size  Founded  Type of ownership  \
# 0  201 to 500 employees     2002  Company - Private
# 1  201 to 500 employees     1997           Contract
# 2  201 to 500 employees     2011   Company - Public
# 3      10000+ employees     1978   Company - Public
# 4   51 to 200 employees     2003  Company - Private
#
#                        Industry                      Sector  \
# 0                   IT Services      Information Technology
# 1  Computer Hardware & Software      Information Technology
# 2  Computer Hardware & Software      Information Technology
# 3     Transportation Management  Transportation & Logistics
# 4                    Consulting           Business Services
#
#                       Revenue                             Competitors
# 0  $100 to $500 million (USD)                         PMSI, myMatrixx
# 1    $25 to $50 million (USD)                                      -1
# 2    Unknown / Non-Applicable  Subsplash, Ministry Brands, Smartsheet
# 3          $10+ billion (USD)             Union Pacific, BNSF Railway
# 4    $10 to $25 million (USD)                                      -1

# %%
#Remove Salary Estimate = -1
df =df[ df['Salary Estimate'] != '-1']

# %% [markdown]
# ### To do
# - Salary Parsing
# - Company name text only
# - Location
# - Age of company
# - job desc parsing

# %% [markdown]
# ## 1. Parsing Salary

# %%
salary = df['Salary Estimate'].apply(lambda x: x.split('(')[0])

#remove K and $ sign
salary = salary.apply(lambda x: x.replace('K','').replace('$',''))
salary.unique()
# Out:
# array(['39-77 ', '70-85', '76-90 ', '38-72 ', '32-64 ', '41-80 ',
#        '34-67 ', '49-91 ', '46-87 ', '59-78 ', '51-94 ', '55-74 ',
#        '62-77 ', '53-95 ', '61-63 ', '47-88 ', '61-99 ', '74-85 ',
#        '48-89 ', '64-122 ', '42-68 ', '53-106 ', '46-84 ', '80-102 ',
#        '50-78 ', '72-128 ', '67-68 ', '69-114 ', '61-103 '], dtype=object)

# %%
df['min_salary'] = salary.apply(lambda x: int(x.split('-')[0]))
df['max_salary'] = salary.apply(lambda x: int(x.split('-')[1]))
df['avg_salary'] = (df['min_salary']+df['max_salary'])/2
df.head(1)
# Out:
#                   Job Title             Salary Estimate  \
# 0  Business Systems Analyst  $39K-$77K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  ***This position is eligible for 100% work fro...     3.2
#
#           Company Name       Location Headquarters                  Size  \
# 0  Healthesystems\n3.2  United States    Tampa, FL  201 to 500 employees
#
#    Founded  Type of ownership     Industry                  Sector  \
# 0     2002  Company - Private  IT Services  Information Technology
#
#                       Revenue      Competitors  min_salary  max_salary  \
# 0  $100 to $500 million (USD)  PMSI, myMatrixx          39          77
#
#    avg_salary
# 0        58.0

# %% [markdown]
# ## 2. Company Name

# %%
df['company_txt'] = df.apply(lambda x: x['Company Name'] if x['Rating'] <0 else x['Company Name'][:-4],axis=1)
df.head(1)
# Out:
#                   Job Title             Salary Estimate  \
# 0  Business Systems Analyst  $39K-$77K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  ***This position is eligible for 100% work fro...     3.2
#
#           Company Name       Location Headquarters                  Size  \
# 0  Healthesystems\n3.2  United States    Tampa, FL  201 to 500 employees
#
#    Founded  Type of ownership     Industry                  Sector  \
# 0     2002  Company - Private  IT Services  Information Technology
#
#                       Revenue      Competitors  min_salary  max_salary  \
# 0  $100 to $500 million (USD)  PMSI, myMatrixx          39          77
#
#    avg_salary     company_txt
# 0        58.0  Healthesystems

# %% [markdown]
# ## 3. Location (State)

# %%
df['job_state'] = df['Location'].apply(lambda x: x.split(','))
df['job_state'] = df['job_state'].apply(lambda x: x[1] if len(x)==2 else x[0])
df.head(1)
# Out:
#                   Job Title             Salary Estimate  \
# 0  Business Systems Analyst  $39K-$77K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  ***This position is eligible for 100% work fro...     3.2
#
#           Company Name       Location Headquarters                  Size  \
# 0  Healthesystems\n3.2  United States    Tampa, FL  201 to 500 employees
#
#    Founded  Type of ownership     Industry                  Sector  \
# 0     2002  Company - Private  IT Services  Information Technology
#
#                       Revenue      Competitors  min_salary  max_salary  \
# 0  $100 to $500 million (USD)  PMSI, myMatrixx          39          77
#
#    avg_salary     company_txt      job_state
# 0        58.0  Healthesystems  United States

# %% [markdown]
# ## 4. Is it in the headquarter?

# %%
df['is_hq'] = df.apply(lambda x: 1 if x['Headquarters'] == x['Location'] else 0,axis=1)
df.head(1)
# Out:
#                   Job Title             Salary Estimate  \
# 0  Business Systems Analyst  $39K-$77K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  ***This position is eligible for 100% work fro...     3.2
#
#           Company Name       Location Headquarters                  Size  \
# 0  Healthesystems\n3.2  United States    Tampa, FL  201 to 500 employees
#
#    Founded  Type of ownership     Industry                  Sector  \
# 0     2002  Company - Private  IT Services  Information Technology
#
#                       Revenue      Competitors  min_salary  max_salary  \
# 0  $100 to $500 million (USD)  PMSI, myMatrixx          39          77
#
#    avg_salary     company_txt      job_state  is_hq
# 0        58.0  Healthesystems  United States      0

# %% [markdown]
# ## 5. Age of company

# %%
df['Age'] = df['Founded'].apply(lambda x: x if x < 1 else 2020-x)
df.head(2)
# Out:
#                   Job Title             Salary Estimate  \
# 0  Business Systems Analyst  $39K-$77K (Glassdoor est.)
# 1  Business Systems Analyst  $39K-$77K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  ***This position is eligible for 100% work fro...     3.2
# 1  Client is seeking Business Systems analysts to...     4.5
#
#                         Company Name        Location    Headquarters  \
# 0                Healthesystems\n3.2   United States       Tampa, FL
# 1  Peterson Technology Partners\n4.5  Northbrook, IL  Park Ridge, IL
#
#                    Size  Founded  Type of ownership  ...  \
# 0  201 to 500 employees     2002  Company - Private  ...
# 1  201 to 500 employees     1997           Contract  ...
#
#                    Sector                     Revenue      Competitors  \
# 0  Information Technology  $100 to $500 million (USD)  PMSI, myMatrixx
# 1  Information Technology    $25 to $50 million (USD)               -1
#
#   min_salary  max_salary  avg_salary                   company_txt  \
# 0         39          77        58.0                Healthesystems
# 1         39          77        58.0  Peterson Technology Partners
#
#        job_state is_hq  Age
# 0  United States     0   18
# 1             IL     0   23
#
# [2 rows x 21 columns]

# %% [markdown]
# ## 6. Job Desc

# %%
#Excel
df['excel'] = df['Job Description'].apply(lambda x: 1 if 'excel' in x.lower() else 0)

#SQL
df['SQL'] = df['Job Description'].apply(lambda x: 1 if 'SQL' in x else 0)

#Python
df['python'] = df['Job Description'].apply(lambda x: 1 if 'python' in x.lower() else 0)

#Tableau
df['tableau'] = df['Job Description'].apply(lambda x: 1 if 'tableau' in x.lower() else 0)

# %%
df['excel'].value_counts()
# Out:
# 1    676
# 0    324
# Name: excel, dtype: int64

# %% [markdown]
# ## Save the data

# %%
df.to_csv('salary_data_cleaned.csv',index=False)
